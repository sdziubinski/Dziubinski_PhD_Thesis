# %%
#-----------------Imports----------------------#
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from scipy.optimize import curve_fit
import math

pd.set_option('display.max_columns', None)

#----Change to main ELOSS directory
os.chdir('C:\\Users\\dziubins\\Home\\Research\\Energy Loss Optical Scintillation System\\')

# %%
import re

for run in [111,113,114,115,117,118,119,120]:
    for chan in range(16,20):
        print(chan)
        # Open the input file for reading
        with open('Data\\run{0}_qdc1_{1}.spec'.format(run, chan), 'r') as file:
            lines = file.readlines()
        file.close()
        # Open the output file for writing
        with open('Data\\run{0}_{1}.txt'.format(run, chan), 'w') as file:
            for line in lines:
                # Assuming numbers with parentheses are in the second column (index 1 if split by spaces)
                # Use regex to remove parentheses around numbers
                modified_line = re.sub(r'\((\d+)\)', r'\1', line)
                file.write(modified_line)
        file.close()
# Out:
# 16
# 17
# 18
# 19
# 16
# 17
# 18
# 19
# 16
# 17
# 18
# 19
# 16
# 17
# 18
# 19
# 16
# 17
# 18
# 19
# 16
# 17
# 18
# 19
# 16
# 17
# 18
# 19
# 16
# 17
# 18
# 19

# %%
import re

for chan in range(16,20):
        print(chan)
        # Open the input file for reading
        with open('Data\\QDC Data\\run{0}_qdc1_{1}.spec'.format(120, chan), 'r') as file:
            lines = file.readlines()
        file.close()
        # Open the output file for writing
        with open('Data\\QDC Data\\run{0}_{1}.txt'.format(120, chan), 'w') as file:
            for line in lines:
                # Assuming numbers with parentheses are in the second column (index 1 if split by spaces)
                # Use regex to remove parentheses around numbers
                modified_line = re.sub(r'\((\d+)\)', r'\1', line)
                file.write(modified_line)
        file.close()
# Out:
# 16
# 17
# 18
# 19

# %%
#---Background 2
#------------------Run 111--------------------------#
run111_16 = pd.read_table("Data\\QDC Data\\run111_16.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run111_17 = pd.read_table("Data\\QDC Data\\run111_17.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run111_18 = pd.read_table("Data\\QDC Data\\run111_18.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run111_19 = pd.read_table("Data\\QDC Data\\run111_19.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
#---Background 3
#------------------Run 113--------------------------#
run113_16 = pd.read_table("Data\\QDC Data\\run113_16.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run113_17 = pd.read_table("Data\\QDC Data\\run113_17.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run113_18 = pd.read_table("Data\\QDC Data\\run113_18.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run113_19 = pd.read_table("Data\\QDC Data\\run113_19.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
#---Background 4
#------------------Run 114--------------------------#
run114_16 = pd.read_table("Data\\QDC Data\\run114_16.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run114_17 = pd.read_table("Data\\QDC Data\\run114_17.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run114_18 = pd.read_table("Data\\QDC Data\\run114_18.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run114_19 = pd.read_table("Data\\QDC Data\\run114_19.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
#---Scintillation 4
#------------------Run 115--------------------------#
run115_16 = pd.read_table("Data\\QDC Data\\run115_16.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run115_17 = pd.read_table("Data\\QDC Data\\run115_17.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run115_18 = pd.read_table("Data\\QDC Data\\run115_18.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run115_19 = pd.read_table("Data\\QDC Data\\run115_19.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
#---Scintillation 3
#------------------Run 117--------------------------#
run117_16 = pd.read_table("Data\\QDC Data\\run117_16.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run117_17 = pd.read_table("Data\\QDC Data\\run117_17.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run117_18 = pd.read_table("Data\\QDC Data\\run117_18.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run117_19 = pd.read_table("Data\\QDC Data\\run117_19.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
#---Scintillation 2
#------------------Run 118--------------------------#
run118_16 = pd.read_table("Data\\QDC Data\\run118_16.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run118_17 = pd.read_table("Data\\QDC Data\\run118_17.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run118_18 = pd.read_table("Data\\QDC Data\\run118_18.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run118_19 = pd.read_table("Data\\QDC Data\\run118_19.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
#---Scintillation 1
#------------------Run 119--------------------------#
run119_16 = pd.read_table("Data\\QDC Data\\run119_16.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run119_17 = pd.read_table("Data\\QDC Data\\run119_17.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run119_18 = pd.read_table("Data\\QDC Data\\run119_18.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
run119_19 = pd.read_table("Data\\QDC Data\\run119_19.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
#------------------Run 120--------------------------#
#run120_16 = pd.read_table("Data\\run120_16.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
#run120_17 = pd.read_table("Data\\run120_17.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
#run120_18 = pd.read_table("Data\\run120_18.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
#run120_19 = pd.read_table("Data\\run120_19.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1,4, figsize=(18,6))
ax1.plot(run115_16['bin'],run115_16['counts']/run115_16['counts'].sum()*10, label='Scintillation')
ax1.plot(run114_16['bin'],run114_16['counts']/run114_16['counts'].sum()*10, label='Background')
ax1.set_xticks(range(0,1000,100))
ax1.set_xticklabels(['0','100','200','300','400','500','600','700','800','900'])
ax1.set_xlim(0,1000)
ax1.set_ylim(0,0.3)
ax1.set_ylabel("Counts normilized by the integral")
ax1.set_xlabel("QDC Value")
ax1.set_title("LV1778 in Channel 1")
ax1.legend()

ax2.plot(run119_17['bin'],run119_17['counts']/run119_17['counts'].sum()*10, label='Scintillation')
#ax2.plot(run113_17['bin'],run113_17['counts']/run113_17['counts'].sum()*10, label='Background')
ax2.set_xticks(range(0,1000,100))
ax2.set_xticklabels(['0','100','200','300','400','500','600','700','800','900'])
ax2.set_xlim(0,1000)
ax2.set_ylim(0,0.7)
ax2.set_xlabel("QDC Value")
ax2.set_title("LV1778 in Channel 2")
ax2.legend()

ax3.plot(run118_18['bin'],run118_18['counts']/run118_18['counts'].sum()*10, label='Scintillation')
ax3.plot(run111_18['bin'],run111_18['counts']/run111_18['counts'].sum()*10, label='Background')
ax3.set_xticks(range(0,1000,100))
ax3.set_xticklabels(['0','100','200','300','400','500','600','700','800','900'])
ax3.set_xlim(0,1000)
ax3.set_ylim(0,0.3)
ax3.set_xlabel("QDC Value")
ax3.set_title("LV1778 in Channel 3")
ax3.legend()

ax4.plot(run117_19['bin'],run117_19['counts']/run117_19['counts'].sum()*10, label='Scintillation')
ax4.plot(run113_19['bin'],run113_19['counts']/run113_19['counts'].sum()*10, label='Background')
ax4.set_xticks(range(0,1000,100))
ax4.set_xticklabels(['0','100','200','300','400','500','600','700','800','900'])
ax4.set_xlim(0,1000)
ax4.set_ylim(0,0.7)
ax4.set_xlabel("QDC Value")
ax4.set_title("LV1778 in Channel 4")
ax4.legend()

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1,4, figsize=(18,6))
ax1.plot(run117_16['bin'],run117_16['counts']/run117_16['counts'].sum()*10, label='Scintillation')
ax1.plot(run113_16['bin'],run113_16['counts']/run113_16['counts'].sum()*10, label='Background')
ax1.set_xticks(range(0,1000,100))
ax1.set_xticklabels(['0','100','200','300','400','500','600','700','800','900'])
ax1.set_xlim(0,1000)
ax1.set_ylim(0,0.3)
ax1.set_ylabel("Counts normilized by the integral")
ax1.set_xlabel("QDC Value")
ax1.set_title("LV1770 in Channel 1")
ax1.legend()

ax2.plot(run115_17['bin'],run115_17['counts']/run115_17['counts'].sum()*10, label='Scintillation')
ax2.plot(run114_17['bin'],run114_17['counts']/run114_17['counts'].sum()*10, label='Background')
ax2.set_xticks(range(0,1000,100))
ax2.set_xticklabels(['0','100','200','300','400','500','600','700','800','900'])
ax2.set_xlim(0,1000)
ax2.set_ylim(0,0.7)
ax2.set_xlabel("QDC Value")
ax2.set_title("LV1770 in Channel 2")
ax2.legend()

ax3.plot(run119_18['bin'],run119_18['counts']/run119_18['counts'].sum()*10, label='Scintillation')
#ax3.plot(run111_18['bin'],run111_18['counts']/run111_18['counts'].sum()*10, label='Background')
ax3.set_xticks(range(0,1000,100))
ax3.set_xticklabels(['0','100','200','300','400','500','600','700','800','900'])
ax3.set_xlim(0,1000)
ax3.set_ylim(0,0.3)
ax3.set_xlabel("QDC Value")
ax3.set_title("LV1770 in Channel 3")
ax3.legend()

ax4.plot(run118_19['bin'],run118_19['counts']/run118_19['counts'].sum()*10, label='Scintillation')
ax4.plot(run111_19['bin'],run111_19['counts']/run111_19['counts'].sum()*10, label="Background")
ax4.set_xticks(range(0,1000,100))
ax4.set_xticklabels(['0','100','200','300','400','500','600','700','800','900'])
ax4.set_xlim(0,1000)
ax4.set_ylim(0,0.7)
ax4.set_xlabel("QDC Value")
ax4.set_title("LV1770 in Channel 4")
ax4.legend()

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1,4, figsize=(18,6))
ax1.plot(run118_16['bin'],run118_16['counts']/run118_16['counts'].sum()*10, label='Scintillation')
ax1.plot(run111_16['bin'],run111_16['counts']/run111_16['counts'].sum()*10, label='Background')
ax1.set_xticks(range(0,1000,100))
ax1.set_xticklabels(['0','100','200','300','400','500','600','700','800','900'])
ax1.set_xlim(0,1000)
ax1.set_ylim(0,0.3)
ax1.set_ylabel("Counts normilized by the integral")
ax1.set_xlabel("QDC Value")
ax1.set_title("LV1771 in Channel 1")
ax1.legend()

ax2.plot(run117_17['bin'],run117_17['counts']/run117_17['counts'].sum()*10, label='Scintillation')
ax2.plot(run113_17['bin'],run113_17['counts']/run113_17['counts'].sum()*10, label='Background')
ax2.set_xticks(range(0,1000,100))
ax2.set_xticklabels(['0','100','200','300','400','500','600','700','800','900'])
ax2.set_xlim(0,1000)
ax2.set_ylim(0,0.7)
ax2.set_xlabel("QDC Value")
ax2.set_title("LV1771 in Channel 2")
ax2.legend()

ax3.plot(run115_18['bin'],run115_18['counts']/run115_18['counts'].sum()*10, label='Scintillation')
ax3.plot(run114_18['bin'],run114_18['counts']/run114_18['counts'].sum()*10, label='Background')
ax3.set_xticks(range(0,1000,100))
ax3.set_xticklabels(['0','100','200','300','400','500','600','700','800','900'])
ax3.set_xlim(0,1000)
ax3.set_ylim(0,0.3)
ax3.set_xlabel("QDC Value")
ax3.set_title("LV1771 in Channel 3")
ax3.legend()

ax4.plot(run119_19['bin'],run119_19['counts']/run119_19['counts'].sum()*10, label='Scintillation')
#ax4.plot(run113_19['bin'],run113_19['counts']/run113_19['counts'].sum()*10, label="Background")
ax4.set_xticks(range(0,1000,100))
ax4.set_xticklabels(['0','100','200','300','400','500','600','700','800','900'])
ax4.set_xlim(0,1000)
ax4.set_ylim(0,0.7)
ax4.set_xlabel("QDC Value")
ax4.set_title("LV1771 in Channel 4")
ax4.legend()

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1,4, figsize=(18,6))
ax1.plot(run119_16['bin'],run119_16['counts']/run119_16['counts'].sum()*10, label='Scintillation')
#ax1.plot(run111_16['bin'],run113_16['counts']/run113_16['counts'].sum()*10, label='Background')
ax1.set_xticks(range(0,1000,100))
ax1.set_xticklabels(['0','100','200','300','400','500','600','700','800','900'])
ax1.set_xlim(0,1000)
ax1.set_ylim(0,0.3)
ax1.set_ylabel("Counts normilized by the integral")
ax1.set_xlabel("QDC Value")
ax1.set_title("LV2101 in Channel 1")
ax1.legend()

ax2.plot(run118_17['bin'],run118_17['counts']/run118_17['counts'].sum()*10, label='Scintillation')
ax2.plot(run111_17['bin'],run111_17['counts']/run111_17['counts'].sum()*10, label='Background')
ax2.set_xticks(range(0,1000,100))
ax2.set_xticklabels(['0','100','200','300','400','500','600','700','800','900'])
ax2.set_xlim(0,1000)
ax2.set_ylim(0,0.7)
ax2.set_xlabel("QDC Value")
ax2.set_title("LV2101 in Channel 2")
ax2.legend()

ax3.plot(run117_18['bin'],run117_18['counts']/run117_18['counts'].sum()*10, label='Scintillation')
ax3.plot(run113_18['bin'],run113_18['counts']/run113_18['counts'].sum()*10, label='Background')
ax3.set_xticks(range(0,1000,100))
ax3.set_xticklabels(['0','100','200','300','400','500','600','700','800','900'])
ax3.set_xlim(0,1000)
ax3.set_ylim(0,0.3)
ax3.set_xlabel("QDC Value")
ax3.set_title("LV2101 in Channel 3")
ax3.legend()

ax4.plot(run115_19['bin'],run115_19['counts']/run115_19['counts'].sum()*10, label='Scintillation')
ax4.plot(run114_19['bin'],run114_19['counts']/run114_19['counts'].sum()*10, label="Background")
ax4.set_xticks(range(0,1000,100))
ax4.set_xticklabels(['0','100','200','300','400','500','600','700','800','900'])
ax4.set_xlim(0,1000)
ax4.set_ylim(0,0.7)
ax4.set_xlabel("QDC Value")
ax4.set_title("LV2101 in Channel 4")
ax4.legend()

# %%
df = pd.read_table("Data\\run113_18.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
df2 = pd.read_table("Data\\run118_18.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
plt.plot(df['bin'],df['counts']/df['counts'].max())
plt.plot(df2['bin'],df2['counts']/df2['counts'].max())

# %%
df = pd.read_table("Data\\QDC Data\\run120_18.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
#df2 = pd.read_table("Data\\run14_18.txt", names=['bin','counts'], sep=' ', skiprows=7, index_col=False)
plt.plot(df['bin'],df['counts']/df['counts'].sum())
#plt.plot(df2['bin'],df2['counts']/df2['counts'].sum())

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1,4, figsize=(18,6))
ax1.plot(run118_16['bin'],run118_16['counts']/run118_16['counts'].sum()*10, label='Scintillation 1')
ax1.plot(run111_16['bin'],run111_16['counts']/run111_16['counts'].sum()*10, label='Background 1')
ax1.plot(run115_18['bin'],run115_18['counts']/run115_18['counts'].sum()*10, label='Scintillation 3')
ax1.plot(run114_18['bin'],run114_18['counts']/run114_18['counts'].sum()*10, label='Background 3')
ax1.set_xticks(range(0,1000,100))
ax1.set_xticklabels(['0','100','200','300','400','500','600','700','800','900'])
ax1.set_xlim(0,1000)
ax1.set_ylim(0,0.3)
ax1.set_ylabel("Counts normilized by the integral")
ax1.set_xlabel("QDC Value")
ax1.set_title("LV1771 in Channel 1")
ax1.legend()

ax2.plot(run117_16['bin'],run117_16['counts']/run117_16['counts'].sum()*10, label='Scintillation 1')
ax2.plot(run113_16['bin'],run113_16['counts']/run113_16['counts'].sum()*10, label='Background 1')
ax2.plot(run119_18['bin'],run119_18['counts']/run119_18['counts'].sum()*10, label='Scintillation 3')
ax2.set_xticks(range(0,1000,100))
ax2.set_xticklabels(['0','100','200','300','400','500','600','700','800','900'])
ax2.set_xlim(0,1000)
ax2.set_ylim(0,0.3)
ax2.set_ylabel("Counts normilized by the integral")
ax2.set_xlabel("QDC Value")
ax2.set_title("LV1770 in Channel 1")
ax2.legend()
